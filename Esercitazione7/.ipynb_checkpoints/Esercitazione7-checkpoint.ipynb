# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import math
import scipy
from scipy.special import erf
import numpy
from numpy import exp
from numpy.lib.scimath import log, sqrt

# %%
plt.rcParams.update({'font.size': 22})
plt.rcParams["figure.figsize"] = (21, 10)

# %%
def selfCorrelation(ts,r):
    selfCorrelations = []
    meanR=np.mean(r)
    variance=np.var(r)
    r=np.array(r-meanR)
    for t in ts:
        selfCorrelations.append(np.sum([((r[i]*r[i+t])/(len(r)-t)) for i in range(1,len(r)-t)]))
    selfCorrelations=np.array(selfCorrelations)/variance
    return selfCorrelations

# %% [markdown]
# ## Exercise 7.02 ##
# In this exercise we are required to study the autocorrelation function of the internal energy obtained by the Montecarlo simulation for three different thermodynamic conditions:
# 1. solid phase: $\rho^\star = 1.1$, $T^\star = 0.8$ (cut-off radius: $r_c = 2.2$)
# 2. liquid phase: $\rho^\star = 0.8$, $T^\star = 1.1$ (cut-off radius: $r_c = 2.5$)
# 3. gas phase: $\rho^\star = 0.05$, $T^\star = 1.2$ (cut-off radius: $r_c = 5.0$)
# The quantities are expressed in the units defined by the Lennard-Jones potential
#
# We will then use the data to decide the size of the blocks by estimating the the size neccesary to have a low correlation

# %%
fig, axs = plt.subplots(1,1);
df1=pd.read_fwf(r'./equilibrationData/output_epot_solid.dat',header=None, infer_nrows=1001)
df2=pd.read_fwf(r'./equilibrationData/output_etot_solid.dat',header=None, infer_nrows=1001)
df3=pd.read_fwf(r'./equilibrationData/output_pres_solid.dat',header=None, infer_nrows=1001)
df1.columns=['nBlocks','estimate','avg','err']
df2.columns=['nBlocks','estimate','avg','err']
df3.columns=['nBlocks','estimate','avg','err']
axs.errorbar(x=df1.nBlocks, y=df1.estimate, yerr=df1.err, label=r'E_pot');
axs.errorbar(x=df2.nBlocks, y=df2.estimate, yerr=df2.err, label=r'E_tot');
axs.errorbar(x=df3.nBlocks, y=df3.estimate, yerr=df3.err, label='pressure');
plt.title("Solid phase")
plt.xlabel("Number of step")
plt.ylabel("Value(natural units)")
plt.legend()

# %% [markdown]
# For the solid state the FCC is a stable configuration, and we don't need any further equilibration. We can now see the liquid and gaseous phases:

# %%
fig, axs = plt.subplots(1,1);
df1=pd.read_fwf(r'./equilibrationData/output_epot_gas.dat',header=None, infer_nrows=5000)
df2=pd.read_fwf(r'./equilibrationData/output_etot_gas.dat',header=None, infer_nrows=5000)
df3=pd.read_fwf(r'./equilibrationData/output_pres_gas.dat',header=None, infer_nrows=5000)
df1.columns=['nBlocks','estimate','avg','err']
df2.columns=['nBlocks','estimate','avg','err']
df3.columns=['nBlocks','estimate','avg','err']
axs.errorbar(x=df1.nBlocks, y=df1.estimate, yerr=df1.err, label=r'E_pot');
axs.errorbar(x=df2.nBlocks, y=df2.estimate, yerr=df2.err, label=r'E_tot');
axs.errorbar(x=df3.nBlocks, y=df3.estimate, yerr=df3.err, label='pressure');
plt.title("Gas phase")
plt.xlabel("Number of step")
plt.ylabel("Value(natural units)")
plt.legend()
plt.show()
fig, axs = plt.subplots(1,1);
df1=pd.read_fwf(r'./equilibrationData/output_epot_liquid.dat',header=None, infer_nrows=5000)
df2=pd.read_fwf(r'./equilibrationData/output_etot_liquid.dat',header=None, infer_nrows=5000)
df3=pd.read_fwf(r'./equilibrationData/output_pres_liquid.dat',header=None, infer_nrows=5000)
df1.columns=['nBlocks','estimate','avg','err']
df2.columns=['nBlocks','estimate','avg','err']
df3.columns=['nBlocks','estimate','avg','err']
axs.errorbar(x=df1.nBlocks, y=df1.estimate, yerr=df1.err, label=r'E_pot');
axs.errorbar(x=df2.nBlocks, y=df2.estimate, yerr=df2.err, label=r'E_tot');
axs.errorbar(x=df3.nBlocks, y=df3.estimate, yerr=df3.err, label='pressure');
plt.title("Liquid phase")
plt.xlabel("Number of step")
plt.ylabel("Value(natural units)")
plt.legend()
plt.show()

# %% [markdown]
# To have an acceeptance rate of $\approx 0.5$ we use a step of $0.1$ in the solid phase, a step of $0.2$ in the liquid phase and a step of

# %%
fig, axs = plt.subplots(1,1);
df=pd.read_fwf(r'./internal_energy_correlation/output_epot_solid.dat',header=None, infer_nrows=1000000)
df.columns=['nBlocks','estimate','avg','err']
axs.errorbar(x=df.nBlocks, y=df.estimate, yerr=df.err, label='average');
axs.set_xlabel('number of steps');
axs.set_ylabel('Potential energy');
fig.suptitle(r'$E_{pot}$ for the solid');

# %%
t=range(0,1000)
selfcorr= selfCorrelation(t,df.avg)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_46032/2920455064.py in <module>
#       1 t=range(0,1000)
# ----> 2 selfcorr= selfCorrelation(t,df.avg)
#
# ~\AppData\Local\Temp/ipykernel_46032/2550969185.py in selfCorrelation(ts, r)
#       5     r=np.array(r-meanR)
#       6     for t in ts:
# ----> 7         selfCorrelations.append(np.sum([((r[i]*r[i+t])/(len(r)-t)) for i in range(1,len(r)-t)]))
#       8     selfCorrelations=np.array(selfCorrelations)/variance
#       9     return selfCorrelations
#
# ~\AppData\Local\Temp/ipykernel_46032/2550969185.py in <listcomp>(.0)
#       5     r=np.array(r-meanR)
#       6     for t in ts:
# ----> 7         selfCorrelations.append(np.sum([((r[i]*r[i+t])/(len(r)-t)) for i in range(1,len(r)-t)]))
#       8     selfCorrelations=np.array(selfCorrelations)/variance
#       9     return selfCorrelations
#
# ...

# %%
plt.xlabel(r'$\Delta t$')
plt.ylabel('autocorrelation')
plt.plot(selfcorr);
plt.title('Autocorrelation');
plt.show();

# %%
df2=pd.read_fwf(r'./MD_MC/MDNVE_MCNVT/output_corr.dat',header=None, infer_nrows=1001)

# %%
datas=df2[1]
g=[]
errs=[]
datas=datas[100].split(';')
for i in range(len(datas)-1):
    tup=tuple(map(float, datas[i][1:-1:].split(',')))
    g.append(tup[1])
    errs.append(tup[2])

# %%
plt.errorbar(x=range(len(g[0::2])),y=g[0::2],yerr=errs[0::2])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
datas[500]
# Out:
# ''
